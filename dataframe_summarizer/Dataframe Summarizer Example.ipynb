# %% [markdown]
# ## Import Required Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from dataframe_stats import StatisticalDescription

# %% [markdown]
# ## Let us load the Iris Dataset

# %%
iris = load_iris()
iris_df = pd.DataFrame(data= np.c_[iris['data']],
                     columns= iris['feature_names'])
iris_df.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 141                6.9               3.1                5.1               2.3
# 121                5.6               2.8                4.9               2.0
# 134                6.1               2.6                5.6               1.4
# 89                 5.5               2.5                4.0               1.3
# 144                6.7               3.3                5.7               2.5
# 0                  5.1               3.5                1.4               0.2
# 37                 4.9               3.6                1.4               0.1
# 10                 5.4               3.7                1.5               0.2
# 93                 5.0               2.3                3.3               1.0
# 88                 5.6               3.0                4.1               1.3

# %% [markdown]
# ## Let us test the Module

# %%
new_df = StatisticalDescription(iris_df.columns)
new_df.populate_df(iris_df)
# Out:
#                               sepal length (cm) sepal width (cm)  \
# column type                             float16          float16
# count                                       150              150
# min                                         4.3                2
# max                                         7.9              4.4
# mean                                    5.84333          3.05733
# median                                      5.8                3
# mode                                          5                3
# percent of zero (or nan) rows                 0                0
# variance                               0.685694         0.189979
# std                                    0.828066         0.435866
# IQR                                         1.3              0.5
# coefficient of variation               0.141711         0.142564
# number of distinct values                    35               23
#
#                               petal length (cm) petal width (cm)
# column type                             float16          float16
# count                                       150              150
# min                                           1              0.1
# max                                         6.9              2.5
# mean                                      3.758          1.19933
# median                                     4.35              1.3
# mode                                        1.4              0.2
# percent of zero (or nan) rows                 0                0
# variance                                3.11628         0.581006
# std                                      1.7653         0.762238
# IQR                                         3.5              1.5
# coefficient of variation               0.469744         0.635551
# number of distinct values                    43               22

# %% [markdown]
# The `column type` characteristics not only shows the type of an object, but also reduces the size of it. Initially, the values in the iris dataset were of type `float64` but the module reduced it to `float16`. This allows to reduce computational time when bigger datasets are used without loosing accuracy

# %% [markdown]
# The dataframe is saved in `csv` format using the following line

# %%
new_df.save_dataframe(iris_df, 'iris_dataset_stats')

# %% [markdown]
# ## Different Dataframe test

# %% [markdown]
# It is not hard to process Iris dataset since it only contains `numerical` features. What if we also input a dataframe with `categorical` data? The following example is for the `titanic` dataset taken from kaggle.

# %%
data_url = "titanic.csv"

titanic_df = pd.read_csv(data_url)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Same Process

# %%
new_df = StatisticalDescription(titanic_df.columns)
new_df.populate_df(titanic_df)
# Out:
#                               PassengerId  Survived    Pclass  \
# column type                         int16      int8      int8
# count                                 891       342       891
# min                                     1         0         1
# max                                   891         1         3
# mean                                  446         1   2.30864
# median                                446         0         3
# mode                                    1         0         3
# percent of zero (or nan) rows           0   61.6162         0
# variance                            66231  0.236772  0.699015
# std                               257.354  0.486592  0.836071
# IQR                                   445         1         1
# coefficient of variation         0.577027  0.486592  0.362149
# number of distinct values             891         2         3
#
#                                                                             Name  \
# column type                                      categorical data (str or mixed)
# count                                                                        891
# min                                                                          NaN
# max                                                                          NaN
# mean                                                                         NaN
# median                                                                       NaN
# mode                           0                        Abbing, Mr. Anthony
# 1...
# percent of zero (or nan) rows                                                100
# variance                                                                     NaN
# std                                                                          NaN
# IQR                                                                          NaN
# coefficient of variation                                                     NaN
# number of distinct values                                                    891
#
#                                                            Sex       Age  \
# column type                    categorical data (str or mixed)   float16
# count                                                      891       714
# min                                                        NaN      0.42
# max                                                        NaN        80
# mean                                                       NaN   29.6991
# median                                                     NaN        28
# mode                                   0    male
# dtype: object        24
# percent of zero (or nan) rows                              100   19.8653
# variance                                                   NaN   169.052
# std                                                        NaN    13.002
# IQR                                                        NaN       NaN
# coefficient of variation                                   NaN  0.437791
# number of distinct values                                    2        88
#
#                                   SibSp     Parch  \
# column type                        int8      int8
# count                               283       213
# min                                   0         0
# max                                   8         6
# mean                            1.64664   1.59624
# median                                0         0
# mode                                  0         0
# percent of zero (or nan) rows   68.2379   76.0943
# variance                        1.21604  0.649728
# std                             1.10274  0.806057
# IQR                                   1         0
# coefficient of variation       0.669692  0.504971
# number of distinct values             7         7
#
#                                                                           Ticket  \
# column type                                      categorical data (str or mixed)
# count                                                                        891
# min                                                                          NaN
# max                                                                          NaN
# mean                                                                         NaN
# median                                                                       NaN
# mode                           0        1601
# 1      347082
# 2    CA. 2343
# dtyp...
# percent of zero (or nan) rows                                                100
# variance                                                                     NaN
# std                                                                          NaN
# IQR                                                                          NaN
# coefficient of variation                                                     NaN
# number of distinct values                                                    681
#
#                                   Fare  \
# column type                    float16
# count                              876
# min                                  0
# max                            512.329
# mean                           32.7556
# median                         14.4542
# mode                              8.05
# percent of zero (or nan) rows   1.6835
# variance                       2469.44
# std                            49.6934
# IQR                            23.0896
# coefficient of variation       1.51709
# number of distinct values          248
#
#                                                                            Cabin  \
# column type                                      categorical data (str or mixed)
# count                                                                        204
# min                                                                          NaN
# max                                                                          NaN
# mean                                                                         NaN
# median                                                                       NaN
# mode                           0        B96 B98
# 1    C23 C25 C27
# 2           ...
# percent of zero (or nan) rows                                            22.8956
# variance                                                                     NaN
# std                                                                          NaN
# IQR                                                                          NaN
# coefficient of variation                                                     NaN
# number of distinct values                                                    147
#
#                                                       Embarked
# column type                    categorical data (str or mixed)
# count                                                      889
# min                                                        NaN
# max                                                        NaN
# mean                                                       NaN
# median                                                     NaN
# mode                                      0    S
# dtype: object
# percent of zero (or nan) rows                          99.7755
# variance                                                   NaN
# std                                                        NaN
# IQR                                                        NaN
# coefficient of variation                                   NaN
# number of distinct values                                    3

# %% [markdown]
# For categorical columns with no numerical entries -> no statistics can be calculated. Thus, we use `NaN` values

# %%
new_df.save_dataframe(titanic_df, 'titanic_dataset_stats')
